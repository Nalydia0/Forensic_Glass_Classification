# %% [markdown]
# <font color='green'><b><h1><span style="text-decoration: underline;">Index</span></h1></b></font>
#
#
#
# <br>
# <br>
#
#    <b>[Introduction To Glass Classification](#Introduction-To-Glass-Classification)</b>
#        <ul>
#             <li>[Case examples of Glass Classification](#Case-examples-of-Glass-Classification)</li>
#             <ul>
#                 <li>[Forensic Uses of glass](#Forensic-Uses-of-glass)</li>
#             </ul>
#         </ul>
#         <br>
#     <b>[Introduction to our problem](#Introduction-to-our-problem)</b>
#     <ul>
#             <li>[Dataset Description](#Dataset-Description)</li>
#     </ul>
#     <br>
#    <b>[Exploratory Data Analysis](#Exploratory-Data-Analysis)</b>
#        <ul>
#     <li>[Descriptive Statistics](#Descriptive-Statistics)</li>
#     <li>[Calculating Abundances of glass types](#Calculating-Abundances-of-glass-types)</li>
#         <ul>
#             <li>[Analysis](#Analysis)</li>
#         </ul>
# </ul>
#
#  <b>[Data Visulisation](#Data-Visulisation)</b>
#     <ul>
#         <li>[Calculating correlation matrixes](#Calculating-correlation-matrixes)</li>
#     </ul>
#
#  <b>[Data Model](#Data-Model)</b>
#  <ul>
#     <li>[Analysis of Classification Report](#Analysis-of-Classification-Report)</li>
#     <ul>
#         <li>[Precision values](#Precision-values)</li>
#         <li>[Recall](#Recall)</li>
#         <li>[F1 score](#F1-score)</li>
#         <li>[Accuracy](#Accuracy)</li>
#     </ul>
#     <li>[Random Forest Vs Support Vector machine](#Random-Forest-Vs-Support-Vector-machine)</li>
#     <ul>
#         <li>[Comparative Accuracy](#Comparative-Accuracy)</li>
#         <li>[ComparativePrecision](#Comparative-Precision)</li>
#         <li>[Comparative Recall](#Comparative-Recall)</li>
#         <li>[Comparative F1 Score](#Comparative-F1-Score)</li>
#         <li>[Why pick random forest?](#Why-pick-random-forest?)</li>
#     </ul>
#
#    </ul>
#
#    <b>[Results](#Results)<b>
#     <ul>
#         <li>[Data Preparation and Exploration](#Data-Preparation-and-Exploration)</li>
#         <ul>
#             <li>[Missing Values](#Missing-Values)</li>
#             <li>[Abudances and Distributions of glass type](#Abudances-and-Distributions-of-glass-type) </li>
#             <ul>
#                 <li>[Abudances of elements and RI](#Abudances-of-elements-and-RI)
#             </ul>
#             <li>[Feature Importance](#Feature-Importance)</li>
#             <li>[Model Building and Evaluation](#Model-Building-and-Evaluation)
#                 <ul>
#                     <li>[Algorithm Choice](#Algorithm-Choice)</li>
#                     <li>[Model Performance and Evaluation](#Model-Performance-and-Evaluation)</li>
#                   <ul>
#                         <li>[Interpretation of Results](#Interpretation-of-Results)</li>
#                             <ul>
#                                 <li>[Resulting Accuracy](#Resulting-Accuracy)</li>
#                                 <li>[Precision and Recall](#Precision-and-Recall)
#                                </ul>
#                     </ul>
#                 </ul>
#             <li>[Confusion Matrix Analysis](#Confusion-Matrix-Analysis)
#     </ul>

# %% [markdown]
# # Introduction To Glass Classification
# <b>[Back To Index](#Index)</b>

# %% [markdown]
# <h1>Main Heading</h1>
#
# <h2>Subheading 1</h2>
# <ul>
#     <li><a href="#section1">Section 1</a></li>
#     <li><a href="#section2">Section 2</a></li>
# </ul>

# %% [markdown]
# Glass is a material that in itself can be made of many different elements. The classification of different types of glass can be very important in different scientific and even non scientific fields. In our case, we're going to look at the field of Criminology and particularly forensic investigations.

# %% [markdown]
# In a crime scene investigation the identification of glass found at the scene can serve as very crucial evidence to the case. If we can ensure accurate classification it can aid in dtermining potential sources of that glass which can often aid in our criminal investigations.
# <br>
#
# Forensic Glass examination's goal is to compare two glass samples, to see if they can be discriminated using chemical, physical or optical properties, i.e by uing Refractive index, elemental composition etc. <br>The logic behind this is, if two samples can be distinguished from any of these observations we can conclude that it did not originate from the same source of broken glass. If they did, however, show to be industinguishable from a sample, then we can conclude it originates from the same source of glass. [4]
# <br>

# %% [markdown]
# ## Case examples of Glass Classification
#
# <b>[Back To Index](#Index)</b>

# %% [markdown]
# The classificaiton of glass and knowing where said glass came from has been instrumental in cases, such as the death of  Tracy Tomko who was struck down by a car during the 2000s. Trace evidence of glass and plastic allowed crime scene investigators to determine she was hit by a car. One of the likely ways this was concluded would have been that the glass would have been identified as lamniated glass sandwhiched between PVC which are what windshields of cars are made out of.[1]
#
# There was also the case of Danny Peterson who was struck down on the 8th of june 2002, six days after being hit by a vehicle. Recovered from the scene of the incident were fragments of glass from the windshield, but also from a headlight. Forensic analysis provided a match to a 2001-2002 Mercury Cougar, this car happenedd to be in a repair shop on the day of the incident. Police investigated a tip from a worried wife that her husband may have been involved in the incident. THye investigated his car and found stress fractures on the bumper of the husband's wife, these stress factures were likely from the impact of hitting Peterson. They later arested the husband as they found that glass fragments inside the car matched those on the body of Danny Peterson. Rivera, the husband, was convicted dof Felonly hit and run andd served jail time. [5]

# %% [markdown]
# There are many studies that have looked at glass classification with a forensic view such as the 2012 study into glass by Umi Kalthom Ahmad et al. https://www.researchgate.net/publication/233419951_FORENSIC_CLASSIFICATION_OF_GLASS_EMPLOYING_REFRACTIVE_INDEX_MEASUREMENT. In their study they are looking at classifying glass by exclusively RI values (Refractive index) This is a measurement of how much light bends when passing through the glass. So in this study they were, in laymans terms, classifying glass by how much a source of light bent when passing through it. The differences in RI index are due to variations in composition. [2]

# %% [markdown]
# ### Forensic Uses of glass
# <b>[Back To Index](#Index)</b>

# %% [markdown]
# As we have illustrated, the identification and classification can be crucial to criminal investigations. There are many cases where, for example, if optical glass, like the glass found in glasses, was left at a crime scene, it might give investigators possible indigators that the criminal wore glasses, if for example, they could then test that optical glass for a perscription they might be able to narrow down search critera.
#
# Also, for crime scene investigators it can also help them construct an idea of what happened at a crime scene, if there was shards of glass from a beer bottle in someone, they might summise that they were struck with this beer bottle which could then lead them to conclude that the victim or the killer was intoxicated.
#
# Glass Classification is crucial as two pieices of glass may appear optically indistinguishable but can often be distinguished chemically [3]

# %% [markdown]
# # Introduction to our problem
# <b>[Back To Index](#Index)</b>

# %% [markdown]
# Our problem requires us to identify and classify glass based on it's composition and it's refractive index. This dataset https://archive.ics.uci.edu/dataset/42/glass+identification Created by B.German looks at classifying glass into 7 classes.
#
# I want to find out and answer a few questions.
#
# 1) How many of each type of glass is in our dataset.
# 2) What abudances of elements are present in each type of glass.
# 3) Which thing i.e element or RI has the highest feature importance.
# 4) Evaluate if my model would be applicable for use in real forensic investigations
# 5) Glass is still majority made with silicon, thusly, I would expect that the most common element across my dataset would be silicon, is this true, if not, why?

# %% [markdown]
# ## Dataset Description
# <b>[Back To Index](#Index)</b>

# %% [markdown]
# This dataset I have selected looks at classifying glass basedd on 9 attributes and classifying them into a variation of our target attribute which is our output attribute.
#
# Nature of the data: This dataset consists of numerical features that represent various chemical attributes of glass samples. There is also a categorical target variable that indicates the type of glass.
#
# Size of our dataset: There are 214 instances, pieces of glass to be classified, these are our rows. There are also 10 attributes which will be our columns.
#
# Source of our data: This was produced by B.German from the USA Forensic Science Service and was downloaded via the UC irvine Machine Learning Repository German,B.. (1987). Glass Identification. UCI Machine Learning Repository. https://doi.org/10.24432/C5WW2P.
#
# Variables/Attributes: Our ataset has the following attributes.
# RI (Refractive index) Numerical <br>
# Na (Sodium) Numerical <br>
# Mg (Magnesium) Numerical <br>
# Al (Aluminum) Numerical <br>
# Si (Silicon) Numerical <br>
# K (Potasium) Numerical <br>
# Ca (Calcium) Numerical  <br>
# Ba (Barium) Numerical <br>
# Fe (Iron) Numerical <br>
# Target (Glass type) Catergorical (This variable has different states) i.e: <br>
#         1) Building Windows (Float Processed)  <br>
#         2) Building Windows (Non Float Processed) <br>
#         3) Vehicle Windows (Float Processed) <br>
#         4) Vehicle Windows (Non float Processed) (None in this database) <br>
#         5) Containers <br>
#         6) Tableware <br>
#         7) Headlamps <br>
#         *** Note: Float or non float refers to how the glass is made. Float is produced by floating molten glass on top of molten tin. Non float means glass not produced via this method, might be blown glass, cast glass etc.
#
#
# Target Variable:
#  The Target Variable is the "Target" attribute, which represents the class of glass type. It has different values depending on the different types of glass looked at.
#
#  Further information: This dataset is very value as it can be used in classifications algorithms to predict the type of glass based on it's chemical composition. It is very useful for a forensic scientist who might be using this to identify glass collected from crime scenes.

# %% [markdown]
# # Exploratory Data Analysis
# <b>[Back To Index](#Index)</b>

# %%
import pandas as pd
##load in our dataset 
## Setup some column names
columns = ['RI','Na','Mg','Al','Si','K','Ca','Ba','Fe','Target']
glass_dataframe = pd.read_csv("glass.csv",names = columns)
glass_dataframe
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Target
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0       1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0       1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0       1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0       1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0       1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...     ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0       7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0       7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0       7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0       7
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0       7
#
# [214 rows x 10 columns]

# %% [markdown]
# ## Descriptive Statistics
# <b>[Back To Index](#Index)</b>

# %%
import pandas as pd

# Load in our CSV file and Produce some Descriptive Statistics.
##Try to make this a little formatted
glass_dataframe = pd.read_csv("glass.csv", names=['RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe', 'Target'])
describe_table = glass_dataframe.describe().reset_index().rename(columns={'index': ''})

# Print the table
print(describe_table.to_string(index=False))
# Out:
#               RI         Na         Mg         Al         Si          K         Ca         Ba         Fe     Target
# count 214.000000 214.000000 214.000000 214.000000 214.000000 214.000000 214.000000 214.000000 214.000000 214.000000
#  mean   1.518365  13.407850   2.684533   1.444907  72.650935   0.497056   8.956963   0.175047   0.057009   2.780374
#   std   0.003037   0.816604   1.442408   0.499270   0.774546   0.652192   1.423153   0.497219   0.097439   2.103739
#   min   1.511150  10.730000   0.000000   0.290000  69.810000   0.000000   5.430000   0.000000   0.000000   1.000000
#   25%   1.516522  12.907500   2.115000   1.190000  72.280000   0.122500   8.240000   0.000000   0.000000   1.000000
#   50%   1.517680  13.300000   3.480000   1.360000  72.790000   0.555000   8.600000   0.000000   0.000000   2.000000
#   75%   1.519157  13.825000   3.600000   1.630000  73.087500   0.610000   9.172500   0.000000   0.100000   3.000000
# ...

# %% [markdown]
# ## Calculating Abundances of glass types
# <b>[Back To Index](#Index)</b>

# %%
import pandas as pd
from tabulate import tabulate
import matplotlib.pyplot as plt
#Load in the glass dataframe 

columns = ['RI','Na','Mg','Al','Si','K','Ca','Ba','Fe','Target']
glass_dataframe = pd.read_csv("glass.csv",names = columns)
# Count the occurrences of each glass type

glass_counts = glass_dataframe['Target'].value_counts().sort_index()

# Plotting this in a bar chart
plt.figure(figsize=(10, 6))
glass_counts.plot(kind='bar', color='skyblue')
plt.title('Number of Types of Glass')
plt.xlabel('Glass Type')
plt.ylabel('Count')
plt.show()

# Create a DataFrame from the counts of the glass types
df = pd.DataFrame({'Number': glass_counts.values}, index=glass_counts.index)

# Sort the DataFrame by the "Number" column in descending order
df_sorted = df.sort_values(by='Number', ascending=False)

# Rename the index and "Target" column to "Type of Glass" and "Number" respectively
df_sorted.index.name = 'Type of Glass'
df_sorted.rename(columns={'Target': 'Number'}, inplace=True)

# Display the sorted counts as a formatted tabl
print(tabulate(df_sorted.reset_index(), headers='keys', tablefmt='fancy_grid', showindex=True))
# Out:
# ╒════╤═════════════════╤══════════╕
# │    │   Type of Glass │   Number │
# ╞════╪═════════════════╪══════════╡
# │  0 │               2 │       76 │
# ├────┼─────────────────┼──────────┤
# │  1 │               1 │       70 │
# ├────┼─────────────────┼──────────┤
# │  2 │               7 │       29 │
# ├────┼─────────────────┼──────────┤
# │  3 │               3 │       17 │
# ├────┼─────────────────┼──────────┤
# │  4 │               5 │       13 │
# ├────┼─────────────────┼──────────┤
# │  5 │               6 │        9 │
# ╘════╧═════════════════╧══════════╛

# %% [markdown]
# ### Analysis
# <b>[Back To Index](#Index)</b>
# ![image.png](attachment:image.png)
# As we can see  in our descriptive statistics, The Refractive index ranges from 1.511 to 1.534 with a mean around 1.518. This is very interest as the refractive index represents how light is bent as it passes through the glass. A more narrow range of refractive index would indicate consistency in optical quality and might mean that the glass came from things like lenses.
#
#
# <br>
# The mean of the RI being 1.518 would suggest that the mean glass samples in this dataset exhibit optical characteristics.
#
#
# <br>
#
# The mean value of sodium in our dataset is 13.41. Sodium is a very common element in glass formations and will influence factors such as viscosity and thermal expansion. Having higher concerntations of sodium can lead to lower melting points during the manufacturing process, but having high content can also mean glass can have a lower durability.
#
# <br>
#
# The mean magnseium content in our glass samples is 2.68 units. Magnesium is often added to enhance durability and resistance of glass. Glass with high Magnesium content are often used in automotive windshields.
#
# <br>
#
# The mean value of Aluminum (Al) in the glass was around 1.44 units. Al is often used in glass to increase restistance to chemical corrosion. Al is also used to control optical properties of class, such as colour and transparency.
#
# <Br>
#
# The mean Silicon( Si) content in glass is 72.65 units. Silicon is the primary component in glass, as it forms the backbone of the molecular structure. Glass that has more Si tend to have a greater structural integrity etc. Silicon Dioxide is one of the most abundant compands in glasses and is resonsible for the transparency of glass.
#
# <Br>
#
# The mean Potassium (K) values in the glass is 0.50 units. Potassium is often used in glass production to lower the Melting Temp and improve the flow of the material during production. Glass with higher K content will often have smoother surfaces and have better optical qualities, lending them to be used in optical lenses and displays.
#
# <br>
#
# The mean Calcium ( Ca) Levels in the glass is aroundd 8.96 units. Calcium often contributes to the strength of the glass. Glass with higheer Ca Levels ten to have a higher resistance to thermal stress.
#
# <BR>
#
# The mean Iron (Fe) content in the glass is about 0.06 units. Iron is a very common impurity in glass. Glass with higher FE content can often result in glass with a green or brown tint which is often undesirable, but does lend it's use to things like beer bottles.
#
# <Br>
#
# The mean Barium (Ba) content in the glass samples is 0.18 units. Ba is often added to modify properties of the glass such as the RI and density. Medical devides and radiation shielding materials will often have a high Ba count.
#
# <Br>
#
# Our target variable represents the types of glass in our dataset. This is determined by the above factors i.e Ri, Ba, etc. These factors will contribute to the overall composition and Properties of the glass. By analysing the above attributes we can gain insights into the relationship between glass type and the attributes.
#
# <br>
#
#  We have also found the number of different types of glass
#   ![image-5.png](attachment:image-5.png)
#   ![image-4.png](attachment:image-4.png)

# %% [markdown]
# # Data Visulisation
# <b>[Back To Index](#Index)</b>

# %% [markdown]
# This Code section is showing our data being Visulaised, here we are plotting, each attrributes frequency in the dataset we will also go on to calculate correlation matrixes because it is important that we establish if there is a linear or non linear relationship, as this would influence our decision of model

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

    
columns = ['RI','Na','Mg','Al','Si','K','Ca','Ba','Fe','Target']
glass_dataframe = pd.read_csv("glass.csv",names = columns)

##plot these as a histogram
glass_dataframe.hist(figsize=(25,20))
plt.tight_layout()
plt.show()

# %% [markdown]
# Analysis of the Histograms showw that Silicon is the most Frequent element, this makes logical sense as silicon is the primary element used in the construction of glass. It's high frequency is consistent with what we'd expect from glass.
#
# Analaysis of the Histograms show that Sodium is the 2nd most frequent element. This makes logical sense as sodium is also often used in the manufacturing process as it is used to lower the melting point of glass and make it more workable during production. Such high frequencies of Sodium indicates that for the majourity of glass some sodium or sodium containing materials has been used in production. Sodium is also sometimes used to affect the Refractive index so that could indicate the use of the glass.
#
# Analysis of the histograms shows that Calcium is the third most frequent. This is interesting as Calcium is often used as a fluxing agent, meaning it is used to help facilitate smelting [6]. However, Calcium is more known for being used to increase the chemical durability of glass. Ca reacts with the hydrated layer of the glass's surface which greattly improves long term glass durability [7]. This high calcium frequency might indicate that the glass has been used in certain industries such as building as Ca is used a lot there.

# %% [markdown]
# ## Calculating correlation matrixes
# <b>[Back To Index](#Index)</b>

# %% [markdown]
# This stage involves us looking at two variables and seeing if they are at all linearlly related to each other. It indicates the relationship between them.
#
# Here we are looking at the pearson correlation coefficent called, whose symbol is R. This measures the strength and direction of the linear relationship between two variables
#
# <br>
# R = 1 = a perfect positive linear relationship, meaning as one variable increases the other does so proportionally.
# <br>
#
# R = -1 = A perfect negative linear relationship, as one variable increases, another decreases
#
# R = 0 indicates no linear relationship between these variables

# %%
correlation_matrix = glass_dataframe.corr()

#Plot a heatmap of the correelstion matrix
plt.figure(figsize=(10,8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Correlation Matrix Heatmap")
plt.show()

# %% [markdown]
# As we can see It's very important to note that there appears to be no perfectly linear relationship here, something we will need to factor in when it comes time to build our model. As it means we will not be able to use models that assume a linear relationship.
#
#
# Most interestingly here is that Magnesium seems to have the most affect on the target variable, possibly meaning that if a glass has magnesium in it, it is very likely to change the target variable i.e mg may have a big impact on the type of glass.
#
# Also interesting is that there is a strong correlation between the element Ca and the refractive index

# %% [markdown]
# # Data Model
# <b>[Back To Index](#Index)</b>

# %% [markdown]
# In order to solve my question as to what is the most common type of glass, and also which element contributes to the target variable the most I have selected to use a random forest Classifier.
#
# <br>
# Random Forest Represents a real robust supervised learning algorithm, making use of multiple decision trees (Known as the "Forest"), which are trained through a process known as bagging. Unlike a singular decision tree, the Random Forest model combines the predictions of several individual trees, which often yields more accurate and stable results. Due to the ensemble nature of random forest, it can harness the collective windows of diverse models, ensuring to mitigate the impact of erroneous predictions from a singular tree
#
#
# <br>
#
# One of the main reasons why I chose this type of model was due to feature importance. Glass contains many different elements which all might contribute differently to the type of glass. Using the random Forect model we can see this as it can help us identify the most influential elements in determining the type of glass. This might provide interesting knowledge that might help during further analysis.
#
#
#
# Another reason I chose this Data Model is because it can ignore a lot of noise. In the real world, glass composition can have a lot of noise attributes to factours such as measurement errors, impurities in the materials or variability in the manufactring process. For example, random Forests could deal with impurities by building multiple Decision Trees on random subsets of the features and samples. As each tree focuses on a different aspect of the data this would reduce the Influence of noise in the individual trees.
#
# <br>
#
# It is important to remember that the relationship between chemical compositon of the glass and its type may not be linear. As randomForest models are good at handiling this, I chose this as a model. In the real world it is very possible that changes to the input features (elements) do not lead to proportional changes in the glass type.
#
#
#
# Take for example, a glass dataset wherein the the type of glass is determined by the various elements such as sodium, calcium and barium. If this was linear this would mean that say as we increase barium this would result in a change in the type of glass. However, in reality, this is often more complex as it might be that, increasing the concerntration of Barium has a nonlinear effect on glass type, wherein small changes in barium have very little impact on glass type initally, but beyond a certain threshold the glass may change drastically. I wanted my model to reflect real world scenarios and I believe that by implementing this method I will have done that.
#
#
#
# There are other models that I could have used, for example I could have used Gradient Boosting machines such as XgBosst and LightGBM. GBMs build strong decision trees sequentially and achieve state of the art performance in many machine learning tasks. However, Random Forest is often better as GBMs often are more computationally expensive and require more tuning than random Forest. Random forest is simpler to implement, less prone to overfitting and often faster to train.
#
# I will go on to compare Support Vector Machines and My random forest to see which is better

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, precision_score, recall_score, f1_score, confusion_matrix
import matplotlib.pyplot as plt
from tabulate import tabulate
import seaborn as sns

# Load the glass dataset
columns = ['RI','Na','Mg','Al','Si','K','Ca','Ba','Fe','Target']
glass_data = pd.read_csv("glass.csv", names=columns)

# Split the dataset into features (x) and target (y)
x = glass_data.drop("Target", axis=1)  # Features
y = glass_data["Target"]  # Target

# Train a Random Forest classifier
rf_classifier = RandomForestClassifier(random_state=2)
rf_classifier.fit(x, y)

# Function to get the feature importance for a specific type of glass
def get_feature_importance_for_type(type_of_glass, randomState):
    rf_classifier = RandomForestClassifier(random_state=randomState)
    rf_classifier.fit(x, y)
    
    # Get the index of the specific type of glass
    glass_index = glass_data[glass_data["Target"] == type_of_glass].index[0]
    
    # Get the feature importance scores for that type of glass
    feature_importance = rf_classifier.feature_importances_
    
    # Get the column names (element names)
    feature_names = x.columns
    
    # Create a DataFrame to store feature importance scores
    importance_df = pd.DataFrame({"Feature": feature_names, "Importance": feature_importance})
    
    # Sort the DataFrame by importance score in descending order
    importance_df = importance_df.sort_values(by="Importance", ascending=False)
    
    # Print the top features (elements) contributing to the specific type of glass
    print(f"Top features contributing to Type {type_of_glass}:")
    print(importance_df)  # Adjust the number as needed
    
    # Plot the feature importance
    plt.figure(figsize=(10, 6))
    plt.barh(importance_df["Feature"], importance_df["Importance"], color='skyblue')
    plt.xlabel('Importance')
    plt.title(f'Feature Importance for Type {type_of_glass}')
    plt.gca().invert_yaxis()  # Invert y-axis to display the most important features at the top
    plt.show()
    
    # Return the importance DataFrame
    return importance_df

# Call the function for each type of glass
get_feature_importance_for_type(1,1)
get_feature_importance_for_type(2,2)
get_feature_importance_for_type(3,3)
get_feature_importance_for_type(5,5)
get_feature_importance_for_type(6,6)
get_feature_importance_for_type(7,7)

# Data Preparation
# Check for missing values
missing_Values = glass_data.isnull().sum()

# Check if there are any missing values
if missing_Values.sum() == 0:
    print("No missing values")
else:
    print("Missing Values:\n", missing_Values)

# Explore distribution of glass types
glass_type_counts = glass_data["Target"].value_counts()
print("Distribution of Glass Types:\n", glass_type_counts)

# Feature Selection
# We obviously don't want type of glass (Target) to be on our X axis so we're gonna just drop that
X = glass_data.drop(columns=["Target"])
y = glass_data["Target"]

# Model Building
# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Initialize and train a Random Forest classifier
rf_classifier = RandomForestClassifier(random_state=42)
rf_classifier.fit(x_train, y_train)

# Make predictions on the testing set
y_pred = rf_classifier.predict(x_test)

# Evaluate model performance
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Generate classification report
report = classification_report(y_test, y_pred, output_dict=True)

# Convert classification report to a table
report_table = []
for label, metrics in report.items():
    if label.isdigit():
        label = f"Class {label}"
    if isinstance(metrics, dict):
        precision = metrics['precision']
        recall = metrics['recall']
        f1Score = metrics['f1-score']
        support = metrics['support']
    else:
        precision = metrics
        recall = '-'
        f1Score = '-'
        support = '-'
    report_table.append([label, precision, recall, f1Score, support])

# Print the table using tabulate
print(tabulate(report_table, headers=['Class', 'Precision', 'Recall', 'F1-Score', 'Support'], tablefmt='pretty'))


# Determine the most common type of glass
most_common_type = glass_type_counts.idxmax()
print("Most Common Type of Glass:", most_common_type)

# Identify the features' importances
feature_importances = pd.Series(rf_classifier.feature_importances_, index=x.columns)
sorted_feature_importance = feature_importances.sort_values(ascending=False)
print("Feature Importances accross the dataset:\n", sorted_feature_importance)

# Plot feature importances
plt.figure(figsize=(11, 7))
sorted_feature_importance.plot(kind='bar')
plt.title('Feature Importances')
plt.xlabel('Features')
plt.ylabel('Importance')
plt.show()
glass_groups = glass_data.groupby("Target")

# Calculate the mean abundances of each element for each type of glass
glass_groups = glass_data.groupby("Target")
element_abundances = glass_groups.mean()

# Print the mean abundances of each element for each type of glass
print("Mean abundances of each element for each type of glass:")
print(element_abundances.to_string())

# Analyse and compare Support Vector Machine to Random Forest
# Initialize models
rf_classifier = RandomForestClassifier(random_state=42)
svm_classifier = SVC(random_state=42)

# Fit models to training data
rf_classifier.fit(x_train, y_train)
svm_classifier.fit(x_train, y_train)


# Make predictions formy forest and my support vector
rf_pred = rf_classifier.predict(x_test)
svm_pred = svm_classifier.predict(x_test)

# Evaluate performance metrics for both model
models = {
    'Random Forest': rf_pred,
    'Support Vector Machine': svm_pred
}

results = {}
for name, pred in models.items():
    accuracy = accuracy_score(y_test, pred)
    precision = precision_score(y_test, pred, average='weighted', zero_division=1)
    recall = recall_score(y_test, pred, average='weighted')
    f1_score_value = f1_score(y_test, pred, average='weighted')
    results[name] = {'Accuracy': accuracy, 'Precision': precision, 'Recall': recall, 'F1_score': f1_score_value}

# Display performance results
results_df = pd.DataFrame(results)
print("Performance Metrics:")
print(results_df)

# Plot confusion matrix for my random forest
plt.figure(figsize=(8,8))
conf_mat = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_mat, annot=True, fmt='d', cmap="Blues", xticklabels=glass_type_counts.index, yticklabels=glass_type_counts.index)
plt.title('Confusion Matrix (Random Forest)')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Top features contributing to Type 1:
#   Feature  Importance
# 2      Mg    0.167826
# 3      Al    0.155353
# 0      RI    0.152139
# 6      Ca    0.131727
# 1      Na    0.093329
# 7      Ba    0.087045
# 4      Si    0.084841
# 5       K    0.083263
# 8      Fe    0.044478
# Top features contributing to Type 2:
#   Feature  Importance
# 3      Al    0.156305
# 2      Mg    0.155935
# 0      RI    0.150244
# 6      Ca    0.127331
# 1      Na    0.097055
# 5       K    0.093688
# 7      Ba    0.086073
# 4      Si    0.083082
# 8      Fe    0.050287
# Top features contributing to Type 3:
#   Feature  Importance
# 2      Mg    0.172535
# 3      Al    0.147976
# 0      RI    0.143778
# 6      Ca    0.129585
# 1      Na    0.106366
# 7      Ba    0.094739
# 4      Si    0.083658
# 5       K    0.082685
# 8      Fe    0.038677
# Top features contributing to Type 5:
#   Feature  Importance
# 3      Al    0.152789
# 0      RI    0.148698
# 2      Mg    0.148300
# 6      Ca    0.134394
# ...

# %% [markdown]
# ## Analysis of Classification Report
# <b>[Back To Index](#Index)</b>

# %% [markdown]
# Our classification report is interesting as it is a report of the performance of our model.
#
# ![image-2.png](attachment:image-2.png)
#
# ### Precision values
# <b>[Back To Index](#Index)</b>
#
# Our precision values tell us the ratio of correctly predicted positive observations to the total of predicted positives. Our model shows us that for type glass 1 ( Building window float processed).
# That 69% of samples predicted as type  1 were actually type 1.
# This isn't great, it's not terrible but isn't great
#
# Our Precision  values for type 2 building_windows_non_float_processed were 90%. This means that 90% of samples that were predicted to be type 2, were actually type 2. This is very good!
#
# Our precision values for type 3,5 and 6, which are vehicle_windows_float_processed,containers and tableware respectively were 100%, Indicating that 100% of samples identified as 3,5 and 6 were actually 3 5 and 6. This is very good
#
# Lastly our Precision values for type 7 which was headlamps was 89%, this means that 89% of samples that were identified to be of type 7, were actually type 7.
# This is good.
#
# ### Recall
# <b>[Back To Index](#Index)</b>
#
# Recall measures the ability of our calssifyer to find all positive instances. It asks the question "Of all actual positive instances how many didd we model correctly identify"
#
# The recall for type 1 shows us that 100% of type 1 samples were correctly identifiedd as type 1.
#
# The recall for type 2 shows us that 64% of type 2 samples were correctly identified as type 2.
#
# The recall for type 3 shows us that 67% of type 3 samples were identified as type 3.
#
# The recall for type 5 shows is that 75% of type 5 samples were correctly identified as type 5 samples.
#
# The recall for both type 6 and 7 shows that 100% of type 6 and 7 samples were correctly identified as type 6 and 7 samples respectively.
#
# ### F1 score
# <b>[Back To Index](#Index)</b>
#
# F1 score is a balance of precision and Recall. A SCORE of 1 means perfect precision and recall, and zero indicates poor performanc. It often takes into account the possibility for False negatives and false positives. For our model we would hope to have 100, but anything above 70 should be decent.
#
# The f1 score for type 1 is 0.81 indicating a closer to perfect recall and precision score balance.
#
# The F1 score for type 2 is 0.75 indicating a medium to high balance of recall and precision score.
#
# The f1 score for type 3 is 0.80 inddicating a closer to perfect recall and precision score balance.
#
# The f1 score for type 5 is 0.80 inddicating a closer to perfect recall and precision score balance.
#
# The f1 score for type 6 is 1. meaning there is a perfect balance between recall andd precision score.
#
# The f1 score for type 7 is 0.94 indicating that there is a near perfect balance between recall and precision.
#
#
# ### Accuracy
#
# <b>[Back To Index](#Index)</b>
#
# Accuracy is the ratio of correctly predicted observations to the total observations. It is a measure of how often our model makes the correct prediction.
#
# Our model has an accuracy of 83.7% meaning that 87.3% of our predictions were correct, this is quite good.

# %% [markdown]
# ## Random Forest Vs Support Vector machine
# <b>[Back To Index](#Index)</b>
#
# ![image.png](attachment:image.png)
#
# After training both Random Forest and a support vector machine, it's clear to see that random forest is a better fit for my dataset.
#
# ### Comparative Accuracy
# <b>[Back To Index](#Index)</b>
#
# My random forest manages to achieve an accuracy of 0.837 versus the support vector machine which only attained 0.326.
#
# This means that my random forest model is making more correct glass type predictions across samples than a SVM.
# This means that random forest is a bonkers 2.5 times more accurate that Support Vector machine.
#
# ### Comparative Precision
# <b>[Back To Index](#Index)</b>
#
# My random forest manages to achieve a precison of 0.867 vesus my Support vector machine which attained 0.780.
# This means that when my Random Forest makes a prediction of the glass type it is more likely to be correct than a support vector machine.
#
# While not massively different in values, it still illustrates that random forest is a lot better.
#
#
# ### Comparative Recall
#
# <b>[Back To Index](#Index)</b>
#
# My random forest manages to achieve a recall of 0.837 versus my support vector machine which only got 0.326
#
# This means that my Random Forest model is better at correctly identifying all  instances of a type of glass , a whopping 2.5 times better
#
# ### Comparative F1 Score
# <b>[Back To Index](#Index)</b>
#
# My random Forest model manages to achieve a F1 score of 0.833 versuses my support vector machine which only manages 0.160.
#
# F1 score is a balance, using mean, between precision and recall. It is higher for my random forest meaning that we have a better balance bewteen recall and precision in this model, a whopping 5.2 times better balance.
#
# ### Why pick random forest?
# <b>[Back To Index](#Index)</b>
#
# There are many reasons why my random forest was better than my support vector machine. One of the really big ones is that the support vector machine uses a linear kernal machine, this is all well and good when relationships are linear, however, as presented by my heatmap ![image-2.png](attachment:image-2.png)
#
# There is clearly no linear relationship, and this is where it struggles. This is what has likely led to the lower scores
#
# Another big reason why Support Vector isn't as good is because it really struggles with imbalanced data.
# ![image-3.png](attachment:image-3.png)
#
# As you can see our data is very imbalanced as some of the type of glass have very little abudnace in our dataset. Support vector really struggles to classify smaller types of glass as it often looks to maximise the margins between the types of glass.
#
# Lastly, Support Vector machines are very sensitive to data scaling and normalisation. Support Vector will have issues with my glass dataset as RI scale will ikley be from 1 to 2, as opposed to the scale of an element which may be from 0 to 100. SUpport vctor may give more importance to the feature with larger values.
#
#
# As datascientists it is very important for us to comapre other models and not get too caught up with just looking at one model. However, after clear analysis it's obvious to see, that in this case random forest is really the best.

# %% [markdown]
# # Results
# <b>[Back To Index](#Index)</b>
#
# As previously discussed I have analysed the Classification report of both models that I used, that being Super Vector Machine and Random Forest. Upon Analysis I found that Random Forest outperforms Super Vector Machine in every classification i.e precision, f1 etc.
#
# This is why my results will focus on my random forest results as the Super Vector results are worse i.e
#
# ![image-19.png](attachment:image-19.png)
#
#
#
#
# ## Data Preparation and Exploration
# <b>[Back To Index](#Index)</b>
#
# ### Missing Values
# <b>[Back To Index](#Index)</b>
#
# In the field of forensic glass analysis and classification, we must have an absence of missing values in our dataset, as making sure there are no missing values is paramount for ensuring integrity and reliability of our analysed results. If we miss out values it can lead to us being less accurate and having issues later down the line when trying to use this as a method of forensic analysis. It is essential that our model produces no missing values.
#
# ![image-7.png](attachment:image-7.png)
#
# Our model thakfully produces no missing values!
#
# ### Abudances and Distributions of glass type
# <b>[Back To Index](#Index)</b>
#
# In our field of forensic glass analysis it's important to take note of the abundances of glass and the distributions of the glass compositions in our forensic samples:
#
# ![image-21.png](attachment:image-21.png)
# ![image-20.png](attachment:image-20.png)
#
# As shown above understanding the types of glass in our dataset and how many there are we can prioritise our forensic resources, especially in cases where certain types of glass are more common.
# I.e we can see type 2 is the most common folloed by type 1
# <br>
#
# Also! Very importantly! It is here where we can observe a very clear class imbalance, i.e How glass type 6 only has 9 instances, but type 2 has over 70, which will prompt us to use specalised models that can address biases and improve our general model performance. As mentioned previously in our Classification report using methods such as Random forest ae able to address these imbalances whereas Models l;ike Support Vector Machine will not be able to account and address these errors.
#
# <b> It is important to note that we have answered one of our inital questions here as we have found out how much of each type of glass is present in our dataset </b>
#
#
#
# #### Abudances of elements and RI
# <b>[Back To Index](#Index)</b>
#
# For forensic scientists it may be important for them to know for the different types of glass, what the mean abundance of elements and RI are. I ensured that my model outputs this and below is this in table format
#
# ![image-16.png](attachment:image-16.png)
#
# <b> Here it's important to note that we have answered one of the inital questions, it does appear that Silicon is the most abundant element which makes sense as the majourity of glass is made out of silicon! </b>
#
#
#
# ## Feature Importance
# <b>[Back To Index](#Index)</b>
#
# The whole field of forensic glass analysis is all about looking at the chemical compositions of glass, which are represented in our model by features such as Refractive Index (Ri), Sodium (Na), Magnesium (Mg, Aluminium (Al) etc, these all ply a massive role in determining the type of glass. By analysing our feature importance scores generated by our random forest algorithm I was able to identify the elements that had the most effect for each glass type. For example, I was able to identify that for glass type seven
# ![image-9.png](attachment:image-9.png)
#
# The most important features for predicting the type of glass were Aluminium, Magnesium and Refractive inex, in that order
#
# Below we can see all of the feature Importances
# ![image-8.png](attachment:image-8.png)
#
# <b> We did also pose a question at the start of this piece of work, wherein we asked the question, which element, or Ri, had the highest feature importance, obviously, for a forensic scientist using this model they may be more interested in the feature importance of a specific piece of glass. Howeverm, it is very important for those forensic data scientists to know what, overall is the model deeming as more important. </b>
#
#  Below shows this feature importance across the model
#  ![image-17.png](attachment:image-17.png)
#
#  We can thusly conclude from this that the model places the most importance on MG,AL and RI. This is good, because while not in that exact order, the top 3 features that are important for every glass type are MG,Al and RI!
#
#
#
# ## Model Building and Evaluation
# <b>[Back To Index](#Index)</b>
#
# ### Algorithm Choice
# <b>[Back To Index](#Index)</b>
#
# The task of my coursework was to produce a model that can be used to accuractly predict the type of glass based on it's elements and refractive index, the purpose of this model is to provide tools to forensic scientists in order to aid in crime scene analysis.
#
# I choose to employ both the use of Random Forest and Super Vector Machine classifcation algorithms. I chose both of them as I considered them both useful for forensic glass classification tasks.  I found that I could use the support vector machine as more of a comparator algorithm, I found that support alone wasn't great because of the non linear relationship demonstrated in my correlation matrix heatmap:
#
# ![image-10.png](attachment:image-10.png)
#
# The Reason why I chose to go with Random forest as the main approach was because it offers a balanced approach to model complexity as well as predictive performance. By providing this model, it allows for forensic scientists to construct further comprehensive glass classification models that are capable of capaurting subtle variations in the glass's composition and can be used to discriminate between glass that is closely related, the type of glass that is often encountered in forensic casework.
#
# ### Model Performance and Evaluation
# <b>[Back To Index](#Index)</b>
#
# ![image-12.png](attachment:image-12.png)
#
#
# As I am particulary interested in forensic glass classification our model performance must extend to more matrixes than just accuracy, we must take note of precison, recall and f1 score. These scores are crucial to forensic data scientists as they provide a clear assessment of the model's ability to correctly classify glass types, while also minimising false negatives and false positives. By having high precision it ensures that any identified glass types are accurate and reliable, while high recall indicates that the model's sensitivity to detecting all the releveant glass types present in our dataset. <br>
# By evaluating all these performane matrics forensic scientists can gain a really deep understanding into what the model's strengths and weaknesses are, allowing them to make informed decisiosn when it comes to forensic casework scenarios.
#
# We have already done a very comprehensive analysis report, but I will briefly go over some more information here about how it relates specifcially to glass classification in the forensic science field.
#
# #### Interpretation of Results
# <b>[Back To Index](#Index)</b>
#
# ##### Resulting Accuracy
# <b>[Back To Index](#Index)</b>
#
# For our model that is used to forensically classify glass, the accuracy <b>directly </b>impacts the reliability and admissibility of expert testimony when it comes to legal and criminal procedings. Having a High Modal Accuracy instills confidence in the classification resulsts and will enhance the forensic scientists' credability as an expert witness.
#
# It is ideal then that our Random Forest had an accuracy of 84% as this is very accurate. It means that our model correctly predicted the glass type for 84% of the samples in the test dataset, not too bad.
#
#
# ##### Precision and Recall
# <b>[Back To Index](#Index)</b>
#
# The precision and Recall metrics play massive roles when it comes to evaluating forensic Glass Classification models' effectuveness in real world forensic examples. Having a very high precision, like our random forest generally did, means there is a massively minimized risk of misidentifying glass types, this prevents erroneous conclusions and other investigative errors. Luckily for us, our random forest showed very high precision across the board ie 86%.
#
# Having a high recall, something our random forest did have, is good as it is a measure of the proportion of acal instances of certain glass types that the model correctly identified. Being able to balance both precision and recall is esentially for optimising model performance and also mainaining high standards of forensic evidence in legal processes.
#
#
#
#
#
# ## Confusion Matrix Analysis
# <b>[Back To Index](#Index)</b>
#
# ![image-13.png](attachment:image-13.png)
#
# Confusion Matrices are very important for providing forensic scientists with very insightful insights into classifical model perfromance. It shows true positives, false positives, true negatives and false negative predictions.
#
# Being able to visualise these predictions through heatmaps enables forensic scientists to identify classification errors, detect patterns of missclassification, and also prioritise areas for further research. By using the confusion matrix analysis forensic scientists can refine classification models and fine tune it for ehanced forenic glass classification.
#
# As we can see for my Random Forest confusion matrix there was really only one false positive wherein a type 1 was classified as a type 6.
# ![image-15.png](attachment:image-15.png)
#
# However, there were more than a few false negatives, interestingly there were 4 false negatives for type 1, wherein the model predicted it'd be two but ended up being one.
#
# ![image-14.png](attachment:image-14.png)
# A possible reason for this could be the fact that what separates the type 1 and 2 is only the method for manufacturing the glass i.e whether it's float or non float. This could be why the method is slightly strugguling more than others.
#
# However, generally, for our test set everything= on the diagnoal is a correct prediction so that's really ideal

# %% [markdown]
# # Conclusion
# <b>[Back To Index](#Index)</b>
#
# In conclusion my development and subsequent evaluation and in-depth analysis of this classification model for use in the field of forensic glass analysis has proven to have some very great results. I made use of primarily the random Forest algorithm as my model, however I did make use of the Support Vector Machine algorithm as a comparison algorithm as I found that it wasn't as affective due to the nonlinear nature of my dataset, among other factors, this model shows very high, but most importantly, consistent precision, recall and accuracy, this indicates that my model is particularly affective in classifying glass types based on the glass's elemental composition and refractive indexes.
# By making use of machine learning techniques I have gained incredible insights into factors that influence glass classification and the model's decision making process.
#
# My feature importance analysis highlights how significant elemental compositions such as Aluminium, Magnesium and refractive index are in classifying glass types, this is crucial as it provides forensic scientists with valuable information for knowing what analysis to prioritise. For example, if scientists know that Aluminium is very important in classifying glass they may want to focus on aluminium analysis as opposed to looking at Iron, this isn't to say iron is ignored, however, a forensic scientist may choose to allocate more resources to aluminium analysis as they know that it has a higher feature importance.
#
# It is very important that I undertook an analysis of the confusion matrix. Having a confusion matrix helps identify, outside of looking at performance reports, classification errors as well as any possible patterns of misclassification, this could lead to us making more informed and targeted strategies for model improvement.
#
# To finally Conclude, my glass classification model holds incredible promise as an invaluable tool in forensic glass analysis, providing forensic scientists enhanced analysis capabilities and furthering the field of forensic science. Taking this model forward, continued refined of this model will further strengthen its effectiveness and applicability to real world forensic investigations, this will ultimately lead to the increased reliability and integrity of forensic evidence in legal and criminal cases. And with that, I have answered my final question, my model is more than applicable to be used in real world forensic science settings.

# %% [markdown]
# # Refrences
# <b>[Back To Index](#Index)</b>

# %% [markdown]
# [1] Carloss, T. (2018) A piece of evidence the size of a quarter helped Akron Police solve a 2000 murder, News 5 Cleveland WEWS. Available at: https://www.news5cleveland.com/news/local-news/oh-summit/this-piece-of-evidence-the-size-of-a-quarter-helped-akron-police-solve-a-2000-murder (Accessed: 29 April 2024).
#
# [2] Ahmad UK, Asmuji NF, Ibrahim R, Kamaruzaman NU. Forensic  classification  of  glass  employing  refractive index  measurement.  Malaysian  Journal  of  Forensic Sciences 2012, 1-4.
# https://www.researchgate.net/publication/233419951_FORENSIC_CLASSIFICATION_OF_GLASS_EMPLOYING_REFRACTIVE_INDEX_MEASUREMENT
#
# [3] Park, S. and Tyner, S. (2019) Evaluation and comparison of methods for forensic glass source conclusions, Forensic Science International. Available at: https://www.sciencedirect.com/science/article/abs/pii/S0379073819304153?via%3Dihub (Accessed: 29 April 2024).
#
# [4] ASTM INTERNATIONAL (2022) Standard test method for determination of concentrations of elements in glass samples using inductively coupled plasma mass spectrometry (ICP-MS) for forensic comparisons, E2330. Available at: https://www.astm.org/e2330-12.html (Accessed: 29 April 2024).
#
# [5] Jones & Bartlett Learning. 2018. Sample Chapter 5: Forensic Soil Analysis. https://samples.jbpub.com/9781284142617/9781284142617_CH05_Girard_SECURE.pdf
#
# [6] Seetharaman, S. (2024) Treatise on process metallurgy: Volume 3: Industrial Processes Vol Vol 3. Edited by Sridhar Seetharaman. San Diego: Elsevier.
# https://www.sciencedirect.com/book/9780080969886/treatise-on-process-metallurgy
#
# [7]
# Mercado-Depierre, S. et al. (2013) ‘Antagonist effects of calcium on borosilicate glass alteration’, Journal of Nuclear Materials, 441(1–3), pp. 402–410. doi:10.1016/j.jnucmat.2013.06.023.
